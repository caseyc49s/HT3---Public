# %%
import pandas as pd
alertl = pd.read_csv('AlertLevel.csv')
rvbsm = pd.read_csv('RvBsm.csv')
summary = pd.read_csv('Summary.csv')
eventappid = pd.read_csv('EventAppID.csv')
host = pd.read_csv('Host.csv')
rvzone = pd.read_csv('RvZone.csv')
evtwarn = pd.read_csv('EvtWarn.csv')
vehclass = pd.read_csv('RvBasicVehClass.csv')
spat = pd.read_csv('Spat.csv')

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 100)

# %%
summary.groupby(['Device','Trip']).size().reset_index().rename(columns={0:'count'}).head()
# Out:
#    Device  Trip  count
# 0    2004     4      1
# 1    2004     8      1
# 2    2004    11      1
# 3    2004    12      1
# 4    2004    13      1

# %%
# unique device and trip : loop over summary 
device = 2004
trip = 12

# %%
summary[(summary['Device'] == device) & (summary['Trip'] == trip)]
# Out:
#    Device  Trip  StartTime  Endtime        UTCTime     TripStart  TodTripStart
# 3    2004    12      20450   136050  1539036877954  43381.926828  43381.718495

# %%
# filter data for the particular device and trip ids from other tables
host_data = host[(host['Device'] == device) & (host['Trip'] == trip)].reset_index().drop(columns=['index'])
rvbsm_data = rvbsm[(rvbsm['Device'] == device) & (rvbsm['Trip'] == trip)].reset_index().drop(columns=['index'])
evt_data = evtwarn[(evtwarn['Device'] == device) & (evtwarn['Trip'] == trip)].reset_index().drop(columns=['index'])
spat_data = spat[(spat['Device'] == device) & (spat['Trip'] == trip)].reset_index().drop(columns=['index'])

# %%
# add unique identifer to join tables on: format: device_trip_time
host_data['merge_id'] = host_data['Device'].astype(str) +'_'+ host_data['Trip'].astype(str)  +'_'+ host_data['Time'].astype(str)
rvbsm_data['merge_id'] = rvbsm_data['Device'].astype(str) +'_'+ rvbsm_data['Trip'].astype(str)  +'_'+ rvbsm_data['Time'].astype(str)
evt_data['merge_id'] = evt_data['Device'].astype(str) +'_'+ evt_data['Trip'].astype(str)  +'_'+ evt_data['Time'].astype(str)
spat_data['merge_id'] = spat_data['Device'].astype(str) +'_'+ spat_data['Trip'].astype(str)  +'_'+ spat_data['Time'].astype(str)

# %%
# update index to unique identifiers for the tables
host_data = host_data.set_index('merge_id')
rvbsm_data = rvbsm_data.set_index('merge_id')
evt_data = evt_data.set_index('merge_id')
spat_data = spat_data.set_index('merge_id')

# %%
# join the tables
ht_ = host_data.join(rvbsm_data,lsuffix='_host',rsuffix='_rvbsm').join(evt_data,rsuffix='_evtwarn').join(spat_data,rsuffix='_spat')

# %%
# save it as a trip (probably)
ht_.to_csv('trip0.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1c7f6cc466a3> in <module>
#       1 # save it as a trip (probably)
# ----> 2 ht_.to_csv('trip0.csv')
#
# NameError: name 'ht_' is not defined

# %%
pd.DataFrame(ht_.columns)
# Out:
#                          0
# 0              Device_host
# 1                Trip_host
# 2                Time_host
# 3          NativeFlag_host
# 4         LocalTimeMS_host
# 5            Latitude_host
# 6           Longitude_host
# 7           Elevation_host
# 8             Heading_host
# 9            GpsSpeed_host
# 10              GpsFixType
# 11          GpsSemiMajAxis
# 12          GpsSemiMinAxis
# 13        GpsOrientSemiMaj
# 14        BrakeStatus_host
# 15                   Speed
# 16            YawRate_host
# 17          LongAccel_host
# 18          ThrottlePosPct
# 19              SteerAngle
# 20              TurnSignal
# 21                Headlamp
# 22                   Wiper
# 23              TransState
# 24  StabilityControlStatus
# 25               ABSStatus
# 26       TracControlStatus
# 27      ClosestIntersectId
# 28                Distance
# 29            Device_rvbsm
# 30              Trip_rvbsm
# 31              Time_rvbsm
# 32                RvDevice
# 33        NativeFlag_rvbsm
# 34       LocalTimeMS_rvbsm
# 35                 BsmPsId
# 36           BasicVehClass
# 37              RvRandomId
# 38          Latitude_rvbsm
# 39         Longitude_rvbsm
# 40         Elevation_rvbsm
# 41           Heading_rvbsm
# 42          GpsSpeed_rvbsm
# 43       BrakeStatus_rvbsm
# 44           YawRate_rvbsm
# 45         LongAccel_rvbsm
# 46                  Device
# 47                    Trip
# 48                    Time
# 49        RvDevice_evtwarn
# 50              NativeFlag
# 51             LocalTimeMS
# 52                    PsId
# 53         RvBasicVehClass
# 54      RvRandomId_evtwarn
# 55              AlertLevel
# 56              EventAppId
# 57                 RvClass
# 58              RvLatitude
# 59             RvLongitude
# 60               RvHeading
# 61             RvElevation
# 62                 RvSpeed
# 63           RvBrakeStatus
# 64               RvYawRate
# 65     RvLongitudinalAccel
# 66            RvTurnSignal
# 67            RvEventFlags
# 68                 RvRange
# 69             RvRangeRate
# 70            RvLongOffset
# 71             RvLatOffset
# 72              HvLatitude
# 73             HvLongitude
# 74               HvHeading
# 75             HvElevation
# 76                 HvSpeed
# 77           HvBrakeStatus
# 78               HvYawRate
# 79     HvLongitudinalAccel
# 80            HvTurnSignal
# 81             Device_spat
# 82               Trip_spat
# 83               Time_spat
# 84         NativeFlag_spat
# 85        LocalTimeMS_spat
# 86             IntersectId
# 87                  LaneId
# 88           MovementPhase
# 89           SignalGroupId
# 90              MinEndTime

# %%
ht_.dropna(thresh=50)
# Out:
#                Device_host  Trip_host  Time_host  NativeFlag_host  \
# merge_id
# 2004_12_21950         2004         12      21950                0
# 2004_12_22000         2004         12      22000                0
# 2004_12_22050         2004         12      22050                0
# 2004_12_22100         2004         12      22100                0
# 2004_12_22150         2004         12      22150                0
# 2004_12_22200         2004         12      22200                0
# 2004_12_48150         2004         12      48150                1
# 2004_12_48250         2004         12      48250                1
# 2004_12_48350         2004         12      48350                1
# 2004_12_48450         2004         12      48450                1
#
#                LocalTimeMS_host  Latitude_host  Longitude_host  \
# merge_id
# 2004_12_21950          80297394      40.279086      -83.531299
# 2004_12_22000          80297894      40.279001      -83.531296
# 2004_12_22050          80298394      40.278937      -83.531295
# 2004_12_22100          80298894      40.278847      -83.531295
# 2004_12_22150          80299394      40.278777      -83.531295
# 2004_12_22200          80299894      40.278723      -83.531295
# 2004_12_48150          80559415      40.258706      -83.463167
# 2004_12_48250          80560415      40.258626      -83.462885
# 2004_12_48350          80561416      40.258525      -83.462534
# 2004_12_48450          80562416      40.258424      -83.462183
#
#                Elevation_host  Heading_host  GpsSpeed_host  GpsFixType  \
# merge_id
# 2004_12_21950       295.42001     177.78999      19.717403           2
# 2004_12_22000       295.51999     178.62000      18.439362           2
# 2004_12_22050       295.51999     179.33000      17.470680           2
# 2004_12_22100       295.62000     179.82001      16.185959           2
# 2004_12_22150       295.62000     180.14000      15.300014           2
# 2004_12_22200       295.72000     179.75999      14.702361           2
# 2004_12_48150       295.62000     110.24000      31.949499           2
# 2004_12_22100               NaN         NaN          NaN   NaN
# 2004_12_22150               NaN         NaN          NaN   NaN
# 2004_12_22200               NaN         NaN          NaN   NaN
# 2004_12_48150            2494.0         1.0   80559500.0   1.0
# 2004_12_48250            2494.0         1.0   80560500.0   1.0
# 2004_12_48350            2494.0         1.0   80561500.0   1.0
# 2004_12_48450            2494.0         1.0   80562500.0   1.0
#
#                RvBasicVehClass  RvRandomId_evtwarn  AlertLevel  EventAppId  \
# merge_id
# 2004_12_21950              NaN                 NaN         NaN         NaN
# 2004_12_22000              NaN                 NaN         NaN         NaN
# 2004_12_22050              NaN                 NaN         NaN         NaN
# 2004_12_22100              NaN                 NaN         NaN         NaN
# 2004_12_22150              NaN                 NaN         NaN         NaN
# 2004_12_22200              NaN                 NaN         NaN         NaN
# 2004_12_48150              0.0              1368.0         2.0         3.0
# 2004_12_48250              0.0              1368.0         2.0         3.0
# 2004_12_48350              0.0              1368.0         2.0         3.0
# 2004_12_48450              0.0              1368.0         2.0         3.0
#
#                RvClass  RvLatitude  RvLongitude  RvHeading  RvElevation  \
# merge_id
# 2004_12_21950      NaN         NaN          NaN        NaN          NaN
# 2004_12_22000      NaN         NaN          NaN        NaN          NaN
# 2004_12_22050      NaN         NaN          NaN        NaN          NaN
# 2004_12_22100      NaN         NaN          NaN        NaN          NaN
# 2004_12_22150      NaN         NaN          NaN        NaN          NaN
# 2004_12_22200      NaN         NaN          NaN        NaN          NaN
# 2004_12_48150      6.0   40.258754   -83.463172    110.250    295.50000
# 2004_12_48250      6.0   40.258647   -83.462790    110.250    295.39999
# 2004_12_48350      6.0   40.258539   -83.462409    110.175    295.20001
# 2004_12_48450      6.0   40.258431   -83.462028    110.350    295.00000
#
#                  RvSpeed  RvBrakeStatus  RvYawRate  RvLongitudinalAccel  \
# merge_id
# 2004_12_21950        NaN            NaN        NaN                  NaN
# 2004_12_22000        NaN            NaN        NaN                  NaN
# 2004_12_22050        NaN            NaN        NaN                  NaN
# 2004_12_22100        NaN            NaN        NaN                  NaN
# 2004_12_22150        NaN            NaN        NaN                  NaN
# 2004_12_22200        NaN            NaN        NaN                  NaN
# 2004_12_48150  34.060001            0.0        0.0                 0.16
# 2004_12_48250  34.040001            0.0        0.0                -0.02
# 2004_12_48350  34.020000            0.0        0.0                 0.20
# 2004_12_48450  34.020000            0.0        0.0                -0.18
#
#                RvTurnSignal  RvEventFlags    RvRange  RvRangeRate  \
# merge_id
# 2004_12_21950           NaN           NaN        NaN          NaN
# 2004_12_22000           NaN           NaN        NaN          NaN
# 2004_12_22050           NaN           NaN        NaN          NaN
# 2004_12_22100           NaN           NaN        NaN          NaN
# 2004_12_22150           NaN           NaN        NaN          NaN
# 2004_12_22200           NaN           NaN        NaN          NaN
# 2004_12_48150         255.0           0.0  10.452876    -2.121639
# 2004_12_48250         255.0           0.0  10.674012    -2.204237
# 2004_12_48350         255.0           0.0   8.518434    -1.742990
# 2004_12_48450           0.0           0.0   5.963946    -0.926577
#
#                RvLongOffset  RvLatOffset  HvLatitude  HvLongitude  HvHeading  \
# merge_id
# 2004_12_21950           NaN          NaN         NaN          NaN        NaN
# 2004_12_22000           NaN          NaN         NaN          NaN        NaN
# 2004_12_22050           NaN          NaN         NaN          NaN        NaN
# 2004_12_22100           NaN          NaN         NaN          NaN        NaN
# 2004_12_22150           NaN          NaN         NaN          NaN        NaN
# 2004_12_22200           NaN          NaN         NaN          NaN        NaN
# 2004_12_48150    -13.039368    -4.904795   40.258686   -83.463096     110.27
# 2004_12_48250    -10.674012    -5.043336   40.258585   -83.462745     110.43
# 2004_12_48350     -8.518434    -5.195783   40.258485   -83.462393     110.53
# 2004_12_48450     -0.706004    -5.365892   40.258383   -83.462042     110.57
#
#                HvElevation    HvSpeed  HvBrakeStatus  HvYawRate  \
# merge_id
# 2004_12_21950          NaN        NaN            NaN        NaN
# 2004_12_22000          NaN        NaN            NaN        NaN
# 2004_12_22050          NaN        NaN            NaN        NaN
# 2004_12_22100          NaN        NaN            NaN        NaN
# 2004_12_22150          NaN        NaN            NaN        NaN
# 2004_12_22200          NaN        NaN            NaN        NaN
# 2004_12_48150    295.51999  31.577778            0.0       0.24
# 2004_12_48250    295.42001  31.611113            0.0       0.24
# 2004_12_48350    295.32001  31.622221            0.0       0.24
# 2004_12_48450    295.12000  31.561111            0.0       0.24
#
#                HvLongitudinalAccel  HvTurnSignal  Device_spat  Trip_spat  \
# merge_id
# 2004_12_21950                  NaN           NaN       2004.0       12.0
# 2004_12_22000                  NaN           NaN       2004.0       12.0
# 2004_12_22050                  NaN           NaN       2004.0       12.0
# 2004_12_22100                  NaN           NaN       2004.0       12.0
# 2004_12_22150                  NaN           NaN       2004.0       12.0
# 2004_12_22200                  NaN           NaN       2004.0       12.0
# 2004_12_48150              -0.0836           0.0          NaN        NaN
# 2004_12_48250               0.0716           0.0          NaN        NaN
# 2004_12_48350               0.2074           0.0          NaN        NaN
# 2004_12_48450               0.1686           0.0          NaN        NaN
#
#                Time_spat  NativeFlag_spat  LocalTimeMS_spat  IntersectId  \
# merge_id
# 2004_12_21950    21950.0              0.0        80297394.0       2103.0
# 2004_12_22000    22000.0              0.0        80297894.0       2103.0
# 2004_12_22050    22050.0              0.0        80298394.0       2103.0
# 2004_12_22100    22100.0              0.0        80298894.0       2103.0
# 2004_12_22150    22150.0              0.0        80299394.0       2103.0
# 2004_12_22200    22200.0              0.0        80299894.0       2103.0
# 2004_12_48150        NaN              NaN               NaN          NaN
# 2004_12_48250        NaN              NaN               NaN          NaN
# 2004_12_48350        NaN              NaN               NaN          NaN
# 2004_12_48450        NaN              NaN               NaN          NaN
#
#                LaneId  MovementPhase  SignalGroupId  MinEndTime
# merge_id
# 2004_12_21950    11.0            4.0            4.0     11054.0
# 2004_12_22000    11.0            4.0            4.0     11061.0
# 2004_12_22050    11.0            4.0            4.0     11065.0
# 2004_12_22100    11.0            4.0            4.0     11069.0
# 2004_12_22150    11.0            4.0            4.0     11074.0
# 2004_12_22200    11.0            4.0            4.0     11080.0
# 2004_12_48150     NaN            NaN            NaN         NaN
# 2004_12_48250     NaN            NaN            NaN         NaN
# 2004_12_48350     NaN            NaN            NaN         NaN
# 2004_12_48450     NaN            NaN            NaN         NaN

# %%
ht_.drop(columns=['LocalTimeMS_spat','NativeFlag_spat','Time_spat','Trip_spat','Device_spat','RvRandomId_evtwarn','RvDevice_evtwarn'])
